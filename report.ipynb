# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
# %qtconsole
import warnings
warnings.filterwarnings('ignore')

# %%
from scene.classifier import *
from scene.data import *
sc = SceneClassifier(limit=10)
# Out:
# Loaded 10 images.
# Loaded 10 ground truth images.

# %%
sc.display(0)
sc.display(1)

# %%
kp, des, img = sc.keypoints(1)
# import cv2 as cv
# img = sc.X_train[1,:,:,:]
# sift = cv.xfeatures2d.SIFT_create()
# gray = cv.cvtColor(sc.X_train[1,:,:,:], cv.COLOR_BGR2GRAY)
# kp = sift.detect(gray, None)
plt.imshow(img)

# %%
hh=sc.hue_feature(sc.X_train[0])
print(hh.shape)
# Out:
# [autoreload of scene.classifier failed: Traceback (most recent call last):
#   File "/Users/alex/miniconda3/envs/cs273a/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/alex/miniconda3/envs/cs273a/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 450, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/alex/miniconda3/envs/cs273a/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 387, in update_generic
#     update(a, b)
#   File "/Users/alex/miniconda3/envs/cs273a/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 357, in update_class
#     update_instances(old, new)
#   File "/Users/alex/miniconda3/envs/cs273a/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 312, in update_instances
#     update_instances(old, new, obj.__dict__, visited)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-2c46a6b82101> in <module>
# ----> 1 hh=sc.hue_feature(sc.X_train[0])
#       2 print(hh.shape)
#
# ~/work/scene/scene/classifier.py in hue_feature(self, X, number_of_bins, n_patches)
#      40     X = sc.X_train[0]
#      41     rem = X.shape[0] % 16
# ---> 42     print(rem)
#      43     if rem > 0:
#      44       X = np.vstack((X, np.zeros((16-rem, X.shape[1], X.shape[2]))))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'vstack'

# %%
# hh=sc.hue_feature(sc.X_train[0])
# number_of_bins=36
# n_patches=260
# X = sc.X_train[0]
# X = X[:208,:,:]
# pr, pg, pb = X[:,:,0], X[:,:,1], X[:,:,2]
# pr = pr.reshape((-1, 256))
# pg = pg.reshape((-1, 256))
# pb = pb.reshape((-1, 256))
# xx, yy = np.mgrid[-8:8,-8:8]
# spatial_weights = np.exp((-(xx**2) - (yy**2)) / 50)

# out = np.zeros((number_of_bins, pr.shape[1]))
# H = np.arctan2(pr+pg-2*pb, np.sqrt(3)*(pr-pg)) + np.pi;
# H[np.isnan(H)] = 0

# saturation=(2/3*(pr**2+pg**2+pb**2-pr*(pg+pb)-pg*pb)+0.01);
# RGB_energy=(np.sum((pr**2+pg**2+pb**2)*(np.ravel(spatial_weights)*np.ones((1,pr.shape[1])))))

# H = np.floor(H/(2*np.pi)*(number_of_bins));
# for jj in range(number_of_bins):
#     out[jj,:] = np.sum(saturation * (np.ravel(spatial_weights) * np.ones((1,pr.shape[1]))) * (H==jj))

# if smooth_flag > 0:
#     for ss in range(1,smooth_flag+1):
#         pass
# out=(2*out+[out(2:size(out,1),:);out(1,:)]+[out(size(out,1),:);out(1:(size(out)-1),:)])/4;
# eps = 1e-3
# out = np.sqrt(out.T / (np.ones((out.shape[1],1)) * RGB_energy + eps)).T
# Out:
# [autoreload of scene.classifier failed: Traceback (most recent call last):
#   File "/Users/alex/miniconda3/envs/cs273a/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/alex/miniconda3/envs/cs273a/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/Users/alex/miniconda3/envs/cs273a/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/alex/miniconda3/envs/cs273a/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
# ...

# %%
hh.shape, des.shape
# Out:
# [autoreload of scene.classifier failed: Traceback (most recent call last):
#   File "/Users/alex/miniconda3/envs/cs273a/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/alex/miniconda3/envs/cs273a/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/Users/alex/miniconda3/envs/cs273a/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/alex/miniconda3/envs/cs273a/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
# ...

# %%
sc.fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-09c54c6157e9> in <module>
# ----> 1 sc.fit()
#
# NameError: name 'sc' is not defined

# %%
sc.plot_loss()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ce448e09027d> in <module>
# ----> 1 sc.plot_loss()
#
# NameError: name 'sc' is not defined
